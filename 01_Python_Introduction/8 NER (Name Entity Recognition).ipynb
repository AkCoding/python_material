# %% [markdown]
# # What is Named Entity Recognition (NER)?
# * It is the process of identifying proper nouns from a piece of text and classifying them into appropriate categories. These categories can be generic like ‘Organization’, ‘Person’, ‘Location’, etc. or they can be tailor-made for a particular application, e.g. ‘Programming Language’, ‘Blogging site’, etc.
#
# * In simpler words, if you want to **find out ‘who’, ‘what’, ‘when’, ‘where’ from a sentence, then NER is your task.**

# %%
# !pip install -U spacy
# !pip install scispacy
# Out:
# Collecting spacy
#   Downloading spacy-3.4.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 2.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4
#   Downloading pydantic-1.10.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 3.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting thinc<8.2.0,>=8.1.0
#   Downloading thinc-8.1.6-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (827 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 827.4/827.4 kB 3.0 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.8-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.8/130.8 kB 1.1 MB/s eta 0:00:001.1 MB/s eta 0:00:01
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.9-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21 kB)
# Collecting smart-open<7.0.0,>=5.2.1
#   Downloading smart_open-6.3.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 3.1 MB/s eta 0:00:00
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.6/181.6 kB 3.3 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting numpy>=1.15.0
#   Downloading numpy-1.24.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 1.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting tqdm<5.0.0,>=4.38.0
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 657.5 kB/s eta 0:00:001m904.4 kB/s eta 0:00:01
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: jinja2 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy) (3.1.2)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36 kB)
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (492 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.6/492.6 kB 1.5 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Requirement already satisfied: packaging>=20.0 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy) (22.0)
# Requirement already satisfied: setuptools in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy) (44.0.0)
# Collecting typer<0.8.0,>=0.3.0
#   Downloading typer-0.7.0-py3-none-any.whl (38 kB)
# Collecting wasabi<1.1.0,>=0.9.1
#   Downloading wasabi-0.10.1-py3-none-any.whl (26 kB)
# Collecting requests<3.0.0,>=2.13.0
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 1.7 MB/s eta 0:00:00
# Collecting spacy-legacy<3.1.0,>=3.0.10
#   Downloading spacy_legacy-3.0.10-py2.py3-none-any.whl (21 kB)
# Collecting pathy>=0.3.5
#   Downloading pathy-0.10.1-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 3.2 MB/s eta 0:00:00
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.8-py3-none-any.whl (17 kB)
# Collecting typing-extensions>=4.1.0
#   Downloading typing_extensions-4.4.0-py3-none-any.whl (26 kB)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2022.12.7-py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 343.7 kB/s eta 0:00:00 kB/s eta 0:00:01:01
# Collecting charset-normalizer<3,>=2
#   Downloading charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.13-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 713.0 kB/s eta 0:00:001m683.0 kB/s eta 0:00:01
# Requirement already satisfied: idna<4,>=2.5 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Collecting blis<0.8.0,>=0.7.8
#   Downloading blis-0.7.9-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 702.1 kB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting confection<1.0.0,>=0.0.1
#   Downloading confection-0.0.3-py3-none-any.whl (32 kB)
# Collecting click<9.0.0,>=7.1.1
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 kB 167.7 kB/s eta 0:00:00 kB/s eta 0:00:01:01
# Requirement already satisfied: MarkupSafe>=2.0 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from jinja2->spacy) (2.1.1)
# Installing collected packages: wasabi, cymem, urllib3, typing-extensions, tqdm, spacy-loggers, spacy-legacy, smart-open, numpy, murmurhash, langcodes, click, charset-normalizer, certifi, catalogue, typer, srsly, requests, pydantic, preshed, blis, pathy, confection, thinc, spacy
# Successfully installed blis-0.7.9 catalogue-2.0.8 certifi-2022.12.7 charset-normalizer-2.1.1 click-8.1.3 confection-0.0.3 cymem-2.0.7 langcodes-3.3.0 murmurhash-1.0.9 numpy-1.24.1 pathy-0.10.1 preshed-3.0.8 pydantic-1.10.2 requests-2.28.1 smart-open-6.3.0 spacy-3.4.4 spacy-legacy-3.0.10 spacy-loggers-1.0.4 srsly-2.4.5 thinc-8.1.6 tqdm-4.64.1 typer-0.7.0 typing-extensions-4.4.0 urllib3-1.26.13 wasabi-0.10.1
# Collecting scispacy
#   Downloading scispacy-0.5.1-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 113.2 kB/s eta 0:00:00MB/s eta 0:00:01
# Collecting nmslib>=1.7.3.6
#   Downloading nmslib-2.1.1-cp38-cp38-manylinux2010_x86_64.whl (13.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 454.3 kB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting joblib
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 1.8 MB/s eta 0:00:001.8 MB/s eta 0:00:01
# Collecting scikit-learn>=0.20.3
#   Downloading scikit_learn-1.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 1.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting pysbd
#   Downloading pysbd-0.3.4-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 kB 1.3 MB/s eta 0:00:00 MB/s eta 0:00:01
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from scispacy) (2.28.1)
# Collecting conllu
#   Downloading conllu-4.5.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: numpy in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from scispacy) (1.24.1)
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from scispacy) (3.4.4)
# Collecting pybind11<2.6.2
#   Downloading pybind11-2.6.1-py2.py3-none-any.whl (188 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 1.3 MB/s eta 0:00:001.3 MB/s eta 0:00:01
# Requirement already satisfied: psutil in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from nmslib>=1.7.3.6->scispacy) (5.9.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from requests<3.0.0,>=2.0.0->scispacy) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from requests<3.0.0,>=2.0.0->scispacy) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from requests<3.0.0,>=2.0.0->scispacy) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from requests<3.0.0,>=2.0.0->scispacy) (2.1.1)
# Collecting scipy>=1.3.2
#   Downloading scipy-1.9.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.8 MB)
#      ╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.8/33.8 MB 1.3 MB/s eta 0:00:26
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/home/hbdev/ml material/venv/lib/python3.8/site-packages/pip/_vendor/urllib3/response.py", line 437, in _error_catcher
#     yield
#   File "/home/hbdev/ml material/venv/lib/python3.8/site-packages/pip/_vendor/urllib3/response.py", line 560, in read
#     data = self._fp_read(amt) if not fp_closed else b""
#   File "/home/hbdev/ml material/venv/lib/python3.8/site-packages/pip/_vendor/urllib3/response.py", line 526, in _fp_read
#     return self._fp.read(amt) if amt is not None else self._fp.read()
#   File "/home/hbdev/ml material/venv/lib/python3.8/site-packages/pip/_vendor/cachecontrol/filewrapper.py", line 90, in read
#     data = self.__fp.read(amt)
#   File "/usr/lib/python3.8/http/client.py", line 459, in read
#     n = self.readinto(b)
#   File "/usr/lib/python3.8/http/client.py", line 503, in readinto
#     n = self.fp.readinto(b)
#   File "/usr/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "/usr/lib/python3.8/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "/usr/lib/python3.8/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/hbdev/ml material/venv/lib/python3.8/site-packages/pip/_internal/cli/base_command.py", line 160, in exc_logging_wrapper
#     status = run_func(*args)
#   File "/home/hbdev/ml material/venv/lib/python3.8/site-packages/pip/_internal/cli/req_command.py", line 247, in wrapper
#     return func(self, options, args)
#   File "/home/hbdev/ml material/venv/lib/python3.8/site-packages/pip/_internal/commands/install.py", line 400, in run
#     requirement_set = resolver.resolve(
#   File "/home/hbdev/ml material/venv/lib/python3.8/site-packages/pip/_internal/resolution/resolvelib/resolver.py", line 92, in resolve
#     result = self._result = resolver.resolve(
#   File "/home/hbdev/ml material/venv/lib/python3.8/site-packages/pip/_vendor/resolvelib/resolvers.py", line 481, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "/home/hbdev/ml material/venv/lib/python3.8/site-packages/pip/_vendor/resolvelib/resolvers.py", line 373, in resolve
#     failure_causes = self._attempt_to_pin_criterion(name)
#   File "/home/hbdev/ml material/venv/lib/python3.8/site-packages/pip/_vendor/resolvelib/resolvers.py", line 213, in _attempt_to_pin_criterion
#     criteria = self._get_updated_criteria(candidate)
#   File "/home/hbdev/ml material/venv/lib/python3.8/site-packages/pip/_vendor/resolvelib/resolvers.py", line 204, in _get_updated_criteria
#     self._add_to_criteria(criteria, requirement, parent=candidate)
#   File "/home/hbdev/ml material/venv/lib/python3.8/site-packages/pip/_vendor/resolvelib/resolvers.py", line 172, in _add_to_criteria
#     if not criterion.candidates:
#   File "/home/hbdev/ml material/venv/lib/python3.8/site-packages/pip/_vendor/resolvelib/structs.py", line 151, in __bool__
#     return bool(self._sequence)
#   File "/home/hbdev/ml material/venv/lib/python3.8/site-packages/pip/_internal/resolution/resolvelib/found_candidates.py", line 155, in __bool__
#     return any(self)
#   File "/home/hbdev/ml material/venv/lib/python3.8/site-packages/pip/_internal/resolution/resolvelib/found_candidates.py", line 143, in <genexpr>
#     return (c for c in iterator if id(c) not in self._incompatible_ids)
#   File "/home/hbdev/ml material/venv/lib/python3.8/site-packages/pip/_internal/resolution/resolvelib/found_candidates.py", line 47, in _iter_built
#     candidate = func()
#   File "/home/hbdev/ml material/venv/lib/python3.8/site-packages/pip/_internal/resolution/resolvelib/factory.py", line 206, in _make_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#   File "/home/hbdev/ml material/venv/lib/python3.8/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 297, in __init__
#     super().__init__(
#   File "/home/hbdev/ml material/venv/lib/python3.8/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 162, in __init__
#     self.dist = self._prepare()
#   File "/home/hbdev/ml material/venv/lib/python3.8/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 231, in _prepare
#     dist = self._prepare_distribution()
#   File "/home/hbdev/ml material/venv/lib/python3.8/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 308, in _prepare_distribution
#     return preparer.prepare_linked_requirement(self._ireq, parallel_builds=True)
#   File "/home/hbdev/ml material/venv/lib/python3.8/site-packages/pip/_internal/operations/prepare.py", line 491, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#   File "/home/hbdev/ml material/venv/lib/python3.8/site-packages/pip/_internal/operations/prepare.py", line 536, in _prepare_linked_requirement
#     local_file = unpack_url(
#   File "/home/hbdev/ml material/venv/lib/python3.8/site-packages/pip/_internal/operations/prepare.py", line 166, in unpack_url
#     file = get_http_url(
#   File "/home/hbdev/ml material/venv/lib/python3.8/site-packages/pip/_internal/operations/prepare.py", line 107, in get_http_url
#     from_path, content_type = download(link, temp_dir.path)
#   File "/home/hbdev/ml material/venv/lib/python3.8/site-packages/pip/_internal/network/download.py", line 147, in __call__
#     for chunk in chunks:
#   File "/home/hbdev/ml material/venv/lib/python3.8/site-packages/pip/_internal/cli/progress_bars.py", line 53, in _rich_progress_bar
#     for chunk in iterable:
#   File "/home/hbdev/ml material/venv/lib/python3.8/site-packages/pip/_internal/network/utils.py", line 63, in response_chunks
#     for chunk in response.raw.stream(
#   File "/home/hbdev/ml material/venv/lib/python3.8/site-packages/pip/_vendor/urllib3/response.py", line 621, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "/home/hbdev/ml material/venv/lib/python3.8/site-packages/pip/_vendor/urllib3/response.py", line 586, in read
#     raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#   File "/usr/lib/python3.8/contextlib.py", line 131, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "/home/hbdev/ml material/venv/lib/python3.8/site-packages/pip/_vendor/urllib3/response.py", line 454, in _error_catcher
#     raise ProtocolError("Connection broken: %r" % e, e)
# pip._vendor.urllib3.exceptions.ProtocolError: ("Connection broken: ConnectionResetError(104, 'Connection reset by peer')", ConnectionResetError(104, 'Connection reset by peer'))

# %%
pip install scispacy
# Out:
# Collecting scispacy
#   Using cached scispacy-0.5.1-py3-none-any.whl (44 kB)
# Collecting conllu
#   Using cached conllu-4.5.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from scispacy) (3.4.4)
# Collecting joblib
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# Requirement already satisfied: numpy in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from scispacy) (1.24.1)
# Collecting pysbd
#   Using cached pysbd-0.3.4-py3-none-any.whl (71 kB)
# Collecting nmslib>=1.7.3.6
#   Using cached nmslib-2.1.1-cp38-cp38-manylinux2010_x86_64.whl (13.4 MB)
# Collecting scikit-learn>=0.20.3
#   Using cached scikit_learn-1.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.7 MB)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from scispacy) (2.28.1)
# Collecting pybind11<2.6.2
#   Using cached pybind11-2.6.1-py2.py3-none-any.whl (188 kB)
# Requirement already satisfied: psutil in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from nmslib>=1.7.3.6->scispacy) (5.9.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from requests<3.0.0,>=2.0.0->scispacy) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from requests<3.0.0,>=2.0.0->scispacy) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from requests<3.0.0,>=2.0.0->scispacy) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from requests<3.0.0,>=2.0.0->scispacy) (1.26.13)
# Collecting scipy>=1.3.2
#   Downloading scipy-1.9.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.8/33.8 MB 1.1 MB/s eta 0:00:00m eta 0:00:010:00:01m
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->scispacy) (3.0.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->scispacy) (4.64.1)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->scispacy) (0.7.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->scispacy) (6.3.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->scispacy) (3.3.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->scispacy) (1.0.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->scispacy) (0.10.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->scispacy) (2.0.7)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->scispacy) (8.1.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->scispacy) (1.10.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->scispacy) (1.0.9)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->scispacy) (3.0.10)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->scispacy) (2.4.5)
# Requirement already satisfied: setuptools in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->scispacy) (44.0.0)
# Requirement already satisfied: pathy>=0.3.5 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->scispacy) (0.10.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->scispacy) (2.0.8)
# Requirement already satisfied: jinja2 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->scispacy) (3.1.2)
# Requirement already satisfied: packaging>=20.0 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->scispacy) (22.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->scispacy) (4.4.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->scispacy) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->scispacy) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->scispacy) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from jinja2->spacy<3.5.0,>=3.4.0->scispacy) (2.1.1)
# Installing collected packages: threadpoolctl, scipy, pysbd, pybind11, joblib, conllu, scikit-learn, nmslib, scispacy
# Successfully installed conllu-4.5.2 joblib-1.2.0 nmslib-2.1.1 pybind11-2.6.1 pysbd-0.3.4 scikit-learn-1.2.0 scipy-1.9.3 scispacy-0.5.1 threadpoolctl-3.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.5.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 1.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: numpy>=1.20.3 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from pandas) (1.24.1)
# Collecting pytz>=2020.1
#   Downloading pytz-2022.7-py2.py3-none-any.whl (499 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.4/499.4 kB 1.7 MB/s eta 0:00:000:00:01m eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: pytz, pandas
# Successfully installed pandas-1.5.2 pytz-2022.7
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.2.4/en_core_sci_sm-0.2.4.tar.gz
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.1/en_core_web_sm-3.4.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 610.8 kB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from en-core-web-sm==3.4.1) (3.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (22.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.64.1)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.9)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.10)
# Requirement already satisfied: pathy>=0.3.5 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.3.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.7)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.1)
# Requirement already satisfied: jinja2 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.1.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (6.3.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.4.5)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.4)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.28.1)
# Requirement already satisfied: numpy>=1.15.0 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.24.1)
# Requirement already satisfied: setuptools in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (44.0.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.10.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.8)
# Requirement already satisfied: typing-extensions>=4.1.0 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.4.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2022.12.7)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/hbdev/ml material/venv/lib/python3.8/site-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.1.1)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.4.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import scispacy                                                            
import spacy                                                                  
from spacy import displacy                                                 
import pandas as pd

# %%
text = """
Google - the WebMaster, possesses various work cultures that ensure employee satisfaction, and their unique approach to performance review is one to embrace. 
If you’ve ever wondered how Google maintains a positive work environment with ambitious employees all year round. In the book, "Work Rules!," Google's Senior Vice President of People Operations Laszlo Bock shared some practices on how this iconic tech company curbed its ideas from the primary assessment activities and turned it into a masterpiece for motivation.
"""

# %%
doc = nlp(text)
spacy.displacy.serve(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr"></br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  - the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     WebMaster
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , possesses various work cultures that ensure employee satisfaction, and their unique approach to performance review is one to embrace. </br>If you’ve ever wondered how
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  maintains a positive work environment with ambitious employees all year round. In the book, &quot;Work Rules!,&quot;
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's Senior Vice President of People Operations
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Laszlo Bock
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  shared some practices on how this iconic tech company curbed its ideas from the primary assessment activities and turned it into a masterpiece for motivation.</br></div>
# </figure>
# </body>
# </html></span>
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5000 ...
# 127.0.0.1 - - [28/Dec/2022 11:16:19] "GET / HTTP/1.1" 200 2462
# 127.0.0.1 - - [28/Dec/2022 11:16:19] "GET /favicon.ico HTTP/1.1" 200 2462
# Shutting down server on port 5000.
